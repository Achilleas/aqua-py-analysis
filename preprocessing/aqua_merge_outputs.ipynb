# %%
from importlib import reload  # Python 3.4+ only.
import h5py
import numpy as np
from analysis.general_utils import aqua_utils, saving_utils
import os

#mats_folder_path = 'E:/astro_axon_green_red/180912_003/data/aqua_no_bound/aqua_res_outputs/'
#save_res_path = 'E:/astro_axon_green_red/180912_003/data/aqua_no_bound/aqua_merged/merged.pkl'

#mats_folder_path = 'E:/astro_axon_green_red/181012_002/data/aqua_no_bound/aqua_res_outputs/'
#save_res_path = 'E:/astro_axon_green_red/181012_002/data/aqua_no_bound/aqua_merged/merged.pkl'

#base_path = 'D:/astro_only/m181129_d190111_c001/data/aqua_bound/'
#base_path = 'D:/astro_only/m181129_d190222_c005/day_0/data/aqua_bound/'
#base_path = 'D:/astro_only/m181129_d190222_c005/day_3/data/aqua_bound/'

#base_path = 'D:/astro_only/m190129_d190226_cx/day_0/data/aqua_bound/'
#base_path = 'D:/astro_only/m190129_d190226_cx/day_2/data/aqua_bound/'


#base_path = 'F:/190220/190220/astro_only/m2000219_d190411_c003/day_0/data/aqua_bound'
#base_path = 'F:/190220/190220/astro_only/m2000219_d190411_c003/day_1/data/aqua_bound'
#base_path = 'F:/190220/190220/astro_only/m2000219_d190411_c004/day_0/data/aqua_bound' 
base_path = 'F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound' 

mats_folder_path = os.path.join(base_path, 'aqua_res_outputs/')
save_res_path = os.path.join(base_path, 'aqua_merged/merged.pkl')

print(mats_folder_path)
print(save_res_path)
# Out:
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs/
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_merged/merged.pkl

# %%
aqua_utils = reload(aqua_utils)

# %%
# Results from aqua run
res_d, input_shape_l, fr_inv, spatial_res = aqua_utils.read_aqua_mats(mats_folder_path)

print('Input shape:', input_shape_l)
print('Result keys:', res_d.keys())
print('Saving...')
# Save results
saving_utils.save_pickle([res_d, input_shape_l, fr_inv, spatial_res], save_res_path)
print('Done!')

print(input_shape_l, fr_inv, spatial_res)
print(res_d.keys())
total_events = len(res_d['tBegin'])
# Out:
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_001_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 0
# 3D index append 0
# (1116,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_002_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 2726
# 3D index append 714604544
# area
# (1065,)
# (1116,)
# circMetric
# (1065,)
# (1116,)
# peri
# (1065,)
# (1116,)
# decayTau
# (1065,)
# (1116,)
# dffMax
# (1065,)
# (1116,)
# dffMax2
# (1065,)
# (1116,)
# (1065,)
# dffMaxFrame
# (1065,)
# (1116,)
# dffMaxPval
# (1065,)
# (1116,)
# dffMaxZ
# (1065,)
# (1116,)
# fall91
# (1065,)
# (1116,)
# rgt1
# (1065, 2)
# (1116, 2)
# rise19
# (1065,)
# (1116,)
# tBegin
# (1065,)
# (1116,)
# tEnd
# (1065,)
# (1116,)
# width11
# (1065,)
# (1116,)
# width55
# (1065,)
# (1116,)
# areaChange
# (1065,)
# (1116,)
# areaChangeRate
# (1065,)
# (1116,)
# areaFrame
# (1065,)
# (1116,)
# propGrow
# (1065,)
# (1116,)
# propGrowOverall
# (1065,)
# (1116,)
# propShrink
# (1065,)
# (1116,)
# propShrinkOverall
# (1065,)
# (1116,)
# t0
# (1065,)
# (1116,)
# t1
# (1065,)
# (1116,)
# x2D
# (1065,)
# (1116,)
# x3D
# (1065,)
# (1116,)
# border_dist2border
# (1065,)
# (1116,)
# clandmark_distAvg
# (1065,)
# (1116,)
# dff_raw
# (1065, 2726)
# (1116, 2726)
# dff_only
# (1065, 2726)
# (1116, 2726)
# d_raw
# (1065, 2726)
# (1116, 2726)
# d_only
# (1065, 2726)
# (1116, 2726)
# event_i_video_segment
# (1065,)
# (1116,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_003_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 5452
# 3D index append 1429209088
# area
# (876,)
# (2181,)
# circMetric
# (876,)
# (2181,)
# peri
# (876,)
# (2181,)
# decayTau
# (876,)
# (2181,)
# dffMax
# (876,)
# (2181,)
# dffMax2
# (876,)
# (2181,)
# (876,)
# dffMaxFrame
# (876,)
# (2181,)
# dffMaxPval
# (876,)
# (2181,)
# dffMaxZ
# (876,)
# (2181,)
# fall91
# (876,)
# (2181,)
# rgt1
# (876, 2)
# (2181, 2)
# rise19
# (876,)
# (2181,)
# tBegin
# (876,)
# (2181,)
# tEnd
# (876,)
# (2181,)
# width11
# (876,)
# (2181,)
# width55
# (876,)
# (2181,)
# areaChange
# (876,)
# (2181,)
# areaChangeRate
# (876,)
# (2181,)
# areaFrame
# (876,)
# (2181,)
# propGrow
# (876,)
# (2181,)
# propGrowOverall
# (876,)
# (2181,)
# propShrink
# (876,)
# (2181,)
# propShrinkOverall
# (876,)
# (2181,)
# t0
# (876,)
# (2181,)
# t1
# (876,)
# (2181,)
# x2D
# (876,)
# (2181,)
# x3D
# (876,)
# (2181,)
# border_dist2border
# (876,)
# (2181,)
# clandmark_distAvg
# (876,)
# (2181,)
# dff_raw
# (876, 2726)
# (2181, 2726)
# dff_only
# (876, 2726)
# (2181, 2726)
# d_raw
# (876, 2726)
# (2181, 2726)
# d_only
# (876, 2726)
# (2181, 2726)
# event_i_video_segment
# (876,)
# (2181,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_004_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 8178
# 3D index append 2143813632
# area
# (841,)
# (3057,)
# circMetric
# (841,)
# (3057,)
# peri
# (841,)
# (3057,)
# decayTau
# (841,)
# (3057,)
# dffMax
# (841,)
# (3057,)
# dffMax2
# (841,)
# (3057,)
# (841,)
# dffMaxFrame
# (841,)
# (3057,)
# dffMaxPval
# (841,)
# (3057,)
# dffMaxZ
# (841,)
# (3057,)
# fall91
# (841,)
# (3057,)
# rgt1
# (841, 2)
# (3057, 2)
# rise19
# (841,)
# (3057,)
# tBegin
# (841,)
# (3057,)
# tEnd
# (841,)
# (3057,)
# width11
# (841,)
# (3057,)
# width55
# (841,)
# (3057,)
# areaChange
# (841,)
# (3057,)
# areaChangeRate
# (841,)
# (3057,)
# areaFrame
# (841,)
# (3057,)
# propGrow
# (841,)
# (3057,)
# propGrowOverall
# (841,)
# (3057,)
# propShrink
# (841,)
# (3057,)
# propShrinkOverall
# (841,)
# (3057,)
# t0
# (841,)
# (3057,)
# t1
# (841,)
# (3057,)
# x2D
# (841,)
# (3057,)
# x3D
# (841,)
# (3057,)
# border_dist2border
# (841,)
# (3057,)
# clandmark_distAvg
# (841,)
# (3057,)
# dff_raw
# (841, 2726)
# (3057, 2726)
# dff_only
# (841, 2726)
# (3057, 2726)
# d_raw
# (841, 2726)
# (3057, 2726)
# d_only
# (841, 2726)
# (3057, 2726)
# event_i_video_segment
# (841,)
# (3057,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_005_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 10904
# 3D index append 2858418176
# area
# (855,)
# (3898,)
# circMetric
# (855,)
# (3898,)
# peri
# (855,)
# (3898,)
# decayTau
# (855,)
# (3898,)
# dffMax
# (855,)
# (3898,)
# dffMax2
# (855,)
# (3898,)
# (855,)
# dffMaxFrame
# (855,)
# (3898,)
# dffMaxPval
# (855,)
# (3898,)
# dffMaxZ
# (855,)
# (3898,)
# fall91
# (855,)
# (3898,)
# rgt1
# (855, 2)
# (3898, 2)
# rise19
# (855,)
# (3898,)
# tBegin
# (855,)
# (3898,)
# tEnd
# (855,)
# (3898,)
# width11
# (855,)
# (3898,)
# width55
# (855,)
# (3898,)
# areaChange
# (855,)
# (3898,)
# areaChangeRate
# (855,)
# (3898,)
# areaFrame
# (855,)
# (3898,)
# propGrow
# (855,)
# (3898,)
# propGrowOverall
# (855,)
# (3898,)
# propShrink
# (855,)
# (3898,)
# propShrinkOverall
# (855,)
# (3898,)
# t0
# (855,)
# (3898,)
# t1
# (855,)
# (3898,)
# x2D
# (855,)
# (3898,)
# x3D
# (855,)
# (3898,)
# border_dist2border
# (855,)
# (3898,)
# clandmark_distAvg
# (855,)
# (3898,)
# dff_raw
# (855, 2726)
# (3898, 2726)
# dff_only
# (855, 2726)
# (3898, 2726)
# d_raw
# (855, 2726)
# (3898, 2726)
# d_only
# (855, 2726)
# (3898, 2726)
# event_i_video_segment
# (855,)
# (3898,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_006_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 13630
# 3D index append 3573022720
# area
# (862,)
# (4753,)
# circMetric
# (862,)
# (4753,)
# peri
# (862,)
# (4753,)
# decayTau
# (862,)
# (4753,)
# dffMax
# (862,)
# (4753,)
# dffMax2
# (862,)
# (4753,)
# (862,)
# dffMaxFrame
# (862,)
# (4753,)
# dffMaxPval
# (862,)
# (4753,)
# dffMaxZ
# (862,)
# (4753,)
# fall91
# (862,)
# (4753,)
# rgt1
# (862, 2)
# (4753, 2)
# rise19
# (862,)
# (4753,)
# tBegin
# (862,)
# (4753,)
# tEnd
# (862,)
# (4753,)
# width11
# (862,)
# (4753,)
# width55
# (862,)
# (4753,)
# areaChange
# (862,)
# (4753,)
# areaChangeRate
# (862,)
# (4753,)
# areaFrame
# (862,)
# (4753,)
# propGrow
# (862,)
# (4753,)
# propGrowOverall
# (862,)
# (4753,)
# propShrink
# (862,)
# (4753,)
# propShrinkOverall
# (862,)
# (4753,)
# t0
# (862,)
# (4753,)
# t1
# (862,)
# (4753,)
# x2D
# (862,)
# (4753,)
# x3D
# (862,)
# (4753,)
# border_dist2border
# (862,)
# (4753,)
# clandmark_distAvg
# (862,)
# (4753,)
# dff_raw
# (862, 2726)
# (4753, 2726)
# dff_only
# (862, 2726)
# (4753, 2726)
# d_raw
# (862, 2726)
# (4753, 2726)
# d_only
# (862, 2726)
# (4753, 2726)
# event_i_video_segment
# (862,)
# (4753,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_007_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 16356
# 3D index append 4287627264
# area
# (828,)
# (5615,)
# circMetric
# (828,)
# (5615,)
# peri
# (828,)
# (5615,)
# decayTau
# (828,)
# (5615,)
# dffMax
# (828,)
# (5615,)
# dffMax2
# (828,)
# (5615,)
# (828,)
# dffMaxFrame
# (828,)
# (5615,)
# dffMaxPval
# (828,)
# (5615,)
# dffMaxZ
# (828,)
# (5615,)
# fall91
# (828,)
# (5615,)
# rgt1
# (828, 2)
# (5615, 2)
# rise19
# (828,)
# (5615,)
# tBegin
# (828,)
# (5615,)
# tEnd
# (828,)
# (5615,)
# width11
# (828,)
# (5615,)
# width55
# (828,)
# (5615,)
# areaChange
# (828,)
# (5615,)
# areaChangeRate
# (828,)
# (5615,)
# areaFrame
# (828,)
# (5615,)
# propGrow
# (828,)
# (5615,)
# propGrowOverall
# (828,)
# (5615,)
# propShrink
# (828,)
# (5615,)
# propShrinkOverall
# (828,)
# (5615,)
# t0
# (828,)
# (5615,)
# t1
# (828,)
# (5615,)
# x2D
# (828,)
# (5615,)
# x3D
# (828,)
# (5615,)
# border_dist2border
# (828,)
# (5615,)
# clandmark_distAvg
# (828,)
# (5615,)
# dff_raw
# (828, 2726)
# (5615, 2726)
# dff_only
# (828, 2726)
# (5615, 2726)
# d_raw
# (828, 2726)
# (5615, 2726)
# d_only
# (828, 2726)
# (5615, 2726)
# event_i_video_segment
# (828,)
# (5615,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_008_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 19082
# 3D index append 5002231808
# area
# (896,)
# (6443,)
# circMetric
# (896,)
# (6443,)
# peri
# (896,)
# (6443,)
# decayTau
# (896,)
# (6443,)
# dffMax
# (896,)
# (6443,)
# dffMax2
# (896,)
# (6443,)
# (896,)
# dffMaxFrame
# (896,)
# (6443,)
# dffMaxPval
# (896,)
# (6443,)
# dffMaxZ
# (896,)
# (6443,)
# fall91
# (896,)
# (6443,)
# rgt1
# (896, 2)
# (6443, 2)
# rise19
# (896,)
# (6443,)
# tBegin
# (896,)
# (6443,)
# tEnd
# (896,)
# (6443,)
# width11
# (896,)
# (6443,)
# width55
# (896,)
# (6443,)
# areaChange
# (896,)
# (6443,)
# areaChangeRate
# (896,)
# (6443,)
# areaFrame
# (896,)
# (6443,)
# propGrow
# (896,)
# (6443,)
# propGrowOverall
# (896,)
# (6443,)
# propShrink
# (896,)
# (6443,)
# propShrinkOverall
# (896,)
# (6443,)
# t0
# (896,)
# (6443,)
# t1
# (896,)
# (6443,)
# x2D
# (896,)
# (6443,)
# x3D
# (896,)
# (6443,)
# border_dist2border
# (896,)
# (6443,)
# clandmark_distAvg
# (896,)
# (6443,)
# dff_raw
# (896, 2726)
# (6443, 2726)
# dff_only
# (896, 2726)
# (6443, 2726)
# d_raw
# (896, 2726)
# (6443, 2726)
# d_only
# (896, 2726)
# (6443, 2726)
# event_i_video_segment
# (896,)
# (6443,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_009_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 21808
# 3D index append 5716836352
# area
# (701,)
# (7339,)
# circMetric
# (701,)
# (7339,)
# peri
# (701,)
# (7339,)
# decayTau
# (701,)
# (7339,)
# dffMax
# (701,)
# (7339,)
# dffMax2
# (701,)
# (7339,)
# (701,)
# dffMaxFrame
# (701,)
# (7339,)
# dffMaxPval
# (701,)
# (7339,)
# dffMaxZ
# (701,)
# (7339,)
# fall91
# (701,)
# (7339,)
# rgt1
# (701, 2)
# (7339, 2)
# rise19
# (701,)
# (7339,)
# tBegin
# (701,)
# (7339,)
# tEnd
# (701,)
# (7339,)
# width11
# (701,)
# (7339,)
# width55
# (701,)
# (7339,)
# areaChange
# (701,)
# (7339,)
# areaChangeRate
# (701,)
# (7339,)
# areaFrame
# (701,)
# (7339,)
# propGrow
# (701,)
# (7339,)
# propGrowOverall
# (701,)
# (7339,)
# propShrink
# (701,)
# (7339,)
# propShrinkOverall
# (701,)
# (7339,)
# t0
# (701,)
# (7339,)
# t1
# (701,)
# (7339,)
# x2D
# (701,)
# (7339,)
# x3D
# (701,)
# (7339,)
# border_dist2border
# (701,)
# (7339,)
# clandmark_distAvg
# (701,)
# (7339,)
# dff_raw
# (701, 2726)
# (7339, 2726)
# dff_only
# (701, 2726)
# (7339, 2726)
# d_raw
# (701, 2726)
# (7339, 2726)
# d_only
# (701, 2726)
# (7339, 2726)
# event_i_video_segment
# (701,)
# (7339,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_010_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 24534
# 3D index append 6431440896
# area
# (704,)
# (8040,)
# circMetric
# (704,)
# (8040,)
# peri
# (704,)
# (8040,)
# decayTau
# (704,)
# (8040,)
# dffMax
# (704,)
# (8040,)
# dffMax2
# (704,)
# (8040,)
# (704,)
# dffMaxFrame
# (704,)
# (8040,)
# dffMaxPval
# (704,)
# (8040,)
# dffMaxZ
# (704,)
# (8040,)
# fall91
# (704,)
# (8040,)
# rgt1
# (704, 2)
# (8040, 2)
# rise19
# (704,)
# (8040,)
# tBegin
# (704,)
# (8040,)
# tEnd
# (704,)
# (8040,)
# width11
# (704,)
# (8040,)
# width55
# (704,)
# (8040,)
# areaChange
# (704,)
# (8040,)
# areaChangeRate
# (704,)
# (8040,)
# areaFrame
# (704,)
# (8040,)
# propGrow
# (704,)
# (8040,)
# propGrowOverall
# (704,)
# (8040,)
# propShrink
# (704,)
# (8040,)
# propShrinkOverall
# (704,)
# (8040,)
# t0
# (704,)
# (8040,)
# t1
# (704,)
# (8040,)
# x2D
# (704,)
# (8040,)
# x3D
# (704,)
# (8040,)
# border_dist2border
# (704,)
# (8040,)
# clandmark_distAvg
# (704,)
# (8040,)
# dff_raw
# (704, 2726)
# (8040, 2726)
# dff_only
# (704, 2726)
# (8040, 2726)
# d_raw
# (704, 2726)
# (8040, 2726)
# d_only
# (704, 2726)
# (8040, 2726)
# event_i_video_segment
# (704,)
# (8040,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_011_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 27260
# 3D index append 7146045440
# area
# (558,)
# (8744,)
# circMetric
# (558,)
# (8744,)
# peri
# (558,)
# (8744,)
# decayTau
# (558,)
# (8744,)
# dffMax
# (558,)
# (8744,)
# dffMax2
# (558,)
# (8744,)
# (558,)
# dffMaxFrame
# (558,)
# (8744,)
# dffMaxPval
# (558,)
# (8744,)
# dffMaxZ
# (558,)
# (8744,)
# fall91
# (558,)
# (8744,)
# rgt1
# (558, 2)
# (8744, 2)
# rise19
# (558,)
# (8744,)
# tBegin
# (558,)
# (8744,)
# tEnd
# (558,)
# (8744,)
# width11
# (558,)
# (8744,)
# width55
# (558,)
# (8744,)
# areaChange
# (558,)
# (8744,)
# areaChangeRate
# (558,)
# (8744,)
# areaFrame
# (558,)
# (8744,)
# propGrow
# (558,)
# (8744,)
# propGrowOverall
# (558,)
# (8744,)
# propShrink
# (558,)
# (8744,)
# propShrinkOverall
# (558,)
# (8744,)
# t0
# (558,)
# (8744,)
# t1
# (558,)
# (8744,)
# x2D
# (558,)
# (8744,)
# x3D
# (558,)
# (8744,)
# border_dist2border
# (558,)
# (8744,)
# clandmark_distAvg
# (558,)
# (8744,)
# dff_raw
# (558, 2726)
# (8744, 2726)
# dff_only
# (558, 2726)
# (8744, 2726)
# d_raw
# (558, 2726)
# (8744, 2726)
# d_only
# (558, 2726)
# (8744, 2726)
# event_i_video_segment
# (558,)
# (8744,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_012_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 29986
# 3D index append 7860649984
# area
# (542,)
# (9302,)
# circMetric
# (542,)
# (9302,)
# peri
# (542,)
# (9302,)
# decayTau
# (542,)
# (9302,)
# dffMax
# (542,)
# (9302,)
# dffMax2
# (542,)
# (9302,)
# (542,)
# dffMaxFrame
# (542,)
# (9302,)
# dffMaxPval
# (542,)
# (9302,)
# dffMaxZ
# (542,)
# (9302,)
# fall91
# (542,)
# (9302,)
# rgt1
# (542, 2)
# (9302, 2)
# rise19
# (542,)
# (9302,)
# tBegin
# (542,)
# (9302,)
# tEnd
# (542,)
# (9302,)
# width11
# (542,)
# (9302,)
# width55
# (542,)
# (9302,)
# areaChange
# (542,)
# (9302,)
# areaChangeRate
# (542,)
# (9302,)
# areaFrame
# (542,)
# (9302,)
# propGrow
# (542,)
# (9302,)
# propGrowOverall
# (542,)
# (9302,)
# propShrink
# (542,)
# (9302,)
# propShrinkOverall
# (542,)
# (9302,)
# t0
# (542,)
# (9302,)
# t1
# (542,)
# (9302,)
# x2D
# (542,)
# (9302,)
# x3D
# (542,)
# (9302,)
# border_dist2border
# (542,)
# (9302,)
# clandmark_distAvg
# (542,)
# (9302,)
# dff_raw
# (542, 2726)
# (9302, 2726)
# dff_only
# (542, 2726)
# (9302, 2726)
# d_raw
# (542, 2726)
# (9302, 2726)
# d_only
# (542, 2726)
# (9302, 2726)
# event_i_video_segment
# (542,)
# (9302,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_013_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 32712
# 3D index append 8575254528
# area
# (837,)
# (9844,)
# circMetric
# (837,)
# (9844,)
# peri
# (837,)
# (9844,)
# decayTau
# (837,)
# (9844,)
# dffMax
# (837,)
# (9844,)
# dffMax2
# (837,)
# (9844,)
# (837,)
# dffMaxFrame
# (837,)
# (9844,)
# dffMaxPval
# (837,)
# (9844,)
# dffMaxZ
# (837,)
# (9844,)
# fall91
# (837,)
# (9844,)
# rgt1
# (837, 2)
# (9844, 2)
# rise19
# (837,)
# (9844,)
# tBegin
# (837,)
# (9844,)
# tEnd
# (837,)
# (9844,)
# width11
# (837,)
# (9844,)
# width55
# (837,)
# (9844,)
# areaChange
# (837,)
# (9844,)
# areaChangeRate
# (837,)
# (9844,)
# areaFrame
# (837,)
# (9844,)
# propGrow
# (837,)
# (9844,)
# propGrowOverall
# (837,)
# (9844,)
# propShrink
# (837,)
# (9844,)
# propShrinkOverall
# (837,)
# (9844,)
# t0
# (837,)
# (9844,)
# t1
# (837,)
# (9844,)
# x2D
# (837,)
# (9844,)
# x3D
# (837,)
# (9844,)
# border_dist2border
# (837,)
# (9844,)
# clandmark_distAvg
# (837,)
# (9844,)
# dff_raw
# (837, 2726)
# (9844, 2726)
# dff_only
# (837, 2726)
# (9844, 2726)
# d_raw
# (837, 2726)
# (9844, 2726)
# d_only
# (837, 2726)
# (9844, 2726)
# event_i_video_segment
# (837,)
# (9844,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_014_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 35438
# 3D index append 9289859072
# area
# (567,)
# (10681,)
# circMetric
# (567,)
# (10681,)
# peri
# (567,)
# (10681,)
# decayTau
# (567,)
# (10681,)
# dffMax
# (567,)
# (10681,)
# dffMax2
# (567,)
# (10681,)
# (567,)
# dffMaxFrame
# (567,)
# (10681,)
# dffMaxPval
# (567,)
# (10681,)
# dffMaxZ
# (567,)
# (10681,)
# fall91
# (567,)
# (10681,)
# rgt1
# (567, 2)
# (10681, 2)
# rise19
# (567,)
# (10681,)
# tBegin
# (567,)
# (10681,)
# tEnd
# (567,)
# (10681,)
# width11
# (567,)
# (10681,)
# width55
# (567,)
# (10681,)
# areaChange
# (567,)
# (10681,)
# areaChangeRate
# (567,)
# (10681,)
# areaFrame
# (567,)
# (10681,)
# propGrow
# (567,)
# (10681,)
# propGrowOverall
# (567,)
# (10681,)
# propShrink
# (567,)
# (10681,)
# propShrinkOverall
# (567,)
# (10681,)
# t0
# (567,)
# (10681,)
# t1
# (567,)
# (10681,)
# x2D
# (567,)
# (10681,)
# x3D
# (567,)
# (10681,)
# border_dist2border
# (567,)
# (10681,)
# clandmark_distAvg
# (567,)
# (10681,)
# dff_raw
# (567, 2726)
# (10681, 2726)
# dff_only
# (567, 2726)
# (10681, 2726)
# d_raw
# (567, 2726)
# (10681, 2726)
# d_only
# (567, 2726)
# (10681, 2726)
# event_i_video_segment
# (567,)
# (10681,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_015_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 38164
# 3D index append 10004463616
# area
# (517,)
# (11248,)
# circMetric
# (517,)
# (11248,)
# peri
# (517,)
# (11248,)
# decayTau
# (517,)
# (11248,)
# dffMax
# (517,)
# (11248,)
# dffMax2
# (517,)
# (11248,)
# (517,)
# dffMaxFrame
# (517,)
# (11248,)
# dffMaxPval
# (517,)
# (11248,)
# dffMaxZ
# (517,)
# (11248,)
# fall91
# (517,)
# (11248,)
# rgt1
# (517, 2)
# (11248, 2)
# rise19
# (517,)
# (11248,)
# tBegin
# (517,)
# (11248,)
# tEnd
# (517,)
# (11248,)
# width11
# (517,)
# (11248,)
# width55
# (517,)
# (11248,)
# areaChange
# (517,)
# (11248,)
# areaChangeRate
# (517,)
# (11248,)
# areaFrame
# (517,)
# (11248,)
# propGrow
# (517,)
# (11248,)
# propGrowOverall
# (517,)
# (11248,)
# propShrink
# (517,)
# (11248,)
# propShrinkOverall
# (517,)
# (11248,)
# t0
# (517,)
# (11248,)
# t1
# (517,)
# (11248,)
# x2D
# (517,)
# (11248,)
# x3D
# (517,)
# (11248,)
# border_dist2border
# (517,)
# (11248,)
# clandmark_distAvg
# (517,)
# (11248,)
# dff_raw
# (517, 2726)
# (11248, 2726)
# dff_only
# (517, 2726)
# (11248, 2726)
# d_raw
# (517, 2726)
# (11248, 2726)
# d_only
# (517, 2726)
# (11248, 2726)
# event_i_video_segment
# (517,)
# (11248,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_016_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 40890
# 3D index append 10719068160
# area
# (402,)
# (11765,)
# circMetric
# (402,)
# (11765,)
# peri
# (402,)
# (11765,)
# decayTau
# (402,)
# (11765,)
# dffMax
# (402,)
# (11765,)
# dffMax2
# (402,)
# (11765,)
# (402,)
# dffMaxFrame
# (402,)
# (11765,)
# dffMaxPval
# (402,)
# (11765,)
# dffMaxZ
# (402,)
# (11765,)
# fall91
# (402,)
# (11765,)
# rgt1
# (402, 2)
# (11765, 2)
# rise19
# (402,)
# (11765,)
# tBegin
# (402,)
# (11765,)
# tEnd
# (402,)
# (11765,)
# width11
# (402,)
# (11765,)
# width55
# (402,)
# (11765,)
# areaChange
# (402,)
# (11765,)
# areaChangeRate
# (402,)
# (11765,)
# areaFrame
# (402,)
# (11765,)
# propGrow
# (402,)
# (11765,)
# propGrowOverall
# (402,)
# (11765,)
# propShrink
# (402,)
# (11765,)
# propShrinkOverall
# (402,)
# (11765,)
# t0
# (402,)
# (11765,)
# t1
# (402,)
# (11765,)
# x2D
# (402,)
# (11765,)
# x3D
# (402,)
# (11765,)
# border_dist2border
# (402,)
# (11765,)
# clandmark_distAvg
# (402,)
# (11765,)
# dff_raw
# (402, 2726)
# (11765, 2726)
# dff_only
# (402, 2726)
# (11765, 2726)
# d_raw
# (402, 2726)
# (11765, 2726)
# d_only
# (402, 2726)
# (11765, 2726)
# event_i_video_segment
# (402,)
# (11765,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_017_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 43616
# 3D index append 11433672704
# area
# (367,)
# (12167,)
# circMetric
# (367,)
# (12167,)
# peri
# (367,)
# (12167,)
# decayTau
# (367,)
# (12167,)
# dffMax
# (367,)
# (12167,)
# dffMax2
# (367,)
# (12167,)
# (367,)
# dffMaxFrame
# (367,)
# (12167,)
# dffMaxPval
# (367,)
# (12167,)
# dffMaxZ
# (367,)
# (12167,)
# fall91
# (367,)
# (12167,)
# rgt1
# (367, 2)
# (12167, 2)
# rise19
# (367,)
# (12167,)
# tBegin
# (367,)
# (12167,)
# tEnd
# (367,)
# (12167,)
# width11
# (367,)
# (12167,)
# width55
# (367,)
# (12167,)
# areaChange
# (367,)
# (12167,)
# areaChangeRate
# (367,)
# (12167,)
# areaFrame
# (367,)
# (12167,)
# propGrow
# (367,)
# (12167,)
# propGrowOverall
# (367,)
# (12167,)
# propShrink
# (367,)
# (12167,)
# propShrinkOverall
# (367,)
# (12167,)
# t0
# (367,)
# (12167,)
# t1
# (367,)
# (12167,)
# x2D
# (367,)
# (12167,)
# x3D
# (367,)
# (12167,)
# border_dist2border
# (367,)
# (12167,)
# clandmark_distAvg
# (367,)
# (12167,)
# dff_raw
# (367, 2726)
# (12167, 2726)
# dff_only
# (367, 2726)
# (12167, 2726)
# d_raw
# (367, 2726)
# (12167, 2726)
# d_only
# (367, 2726)
# (12167, 2726)
# event_i_video_segment
# (367,)
# (12167,)
# F:/190220/190220/astro_only/m2000219_d190411_c004/day_1/data/aqua_bound\aqua_res_outputs\190412_001_018_reg.tif-res.mat
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 46342
# 3D index append 12148277248
# area
# (381,)
# (12534,)
# circMetric
# (381,)
# (12534,)
# peri
# (381,)
# (12534,)
# decayTau
# (381,)
# (12534,)
# dffMax
# (381,)
# (12534,)
# dffMax2
# (381,)
# (12534,)
# (381,)
# dffMaxFrame
# (381,)
# (12534,)
# dffMaxPval
# (381,)
# (12534,)
# dffMaxZ
# (381,)
# (12534,)
# fall91
# (381,)
# (12534,)
# rgt1
# (381, 2)
# (12534, 2)
# rise19
# (381,)
# (12534,)
# tBegin
# (381,)
# (12534,)
# tEnd
# (381,)
# (12534,)
# width11
# (381,)
# (12534,)
# width55
# (381,)
# (12534,)
# areaChange
# (381,)
# (12534,)
# areaChangeRate
# (381,)
# (12534,)
# areaFrame
# (381,)
# (12534,)
# propGrow
# (381,)
# (12534,)
# propGrowOverall
# (381,)
# (12534,)
# propShrink
# (381,)
# (12534,)
# propShrinkOverall
# (381,)
# (12534,)
# t0
# (381,)
# (12534,)
# t1
# (381,)
# (12534,)
# x2D
# (381,)
# (12534,)
# x3D
# (381,)
# (12534,)
# border_dist2border
# (381,)
# (12534,)
# clandmark_distAvg
# (381,)
# (12534,)
# dff_raw
# (381, 2726)
# (12534, 2726)
# dff_only
# (381, 2726)
# (12534, 2726)
# d_raw
# (381, 2726)
# (12534, 2726)
# d_only
# (381, 2726)
# (12534, 2726)
# event_i_video_segment
# (381,)
# (12534,)
# 18
# 18
# Input shape: [array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64)]
# Result keys: dict_keys(['area', 'circMetric', 'peri', 'decayTau', 'dffMax', 'dffMax2', 'dffMaxFrame', 'dffMaxPval', 'dffMaxZ', 'fall91', 'rgt1', 'rise19', 'tBegin', 'tEnd', 'width11', 'width55', 'areaChange', 'areaChangeRate', 'areaFrame', 'propGrow', 'propGrowOverall', 'propShrink', 'propShrinkOverall', 't0', 't1', 'x2D', 'x3D', 'border_mask', 'clandmark_mask', 'clandmark_center', 'border_dist2border', 'clandmark_distAvg', 'dff_raw', 'dff_only', 'd_raw', 'd_only', 'event_i_video_segment'])
# Saving...
# Done!
# [array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64), array([ 512,  512, 2726], dtype=uint64)] 0.097 0.1835
# dict_keys(['area', 'circMetric', 'peri', 'decayTau', 'dffMax', 'dffMax2', 'dffMaxFrame', 'dffMaxPval', 'dffMaxZ', 'fall91', 'rgt1', 'rise19', 'tBegin', 'tEnd', 'width11', 'width55', 'areaChange', 'areaChangeRate', 'areaFrame', 'propGrow', 'propGrowOverall', 'propShrink', 'propShrinkOverall', 't0', 't1', 'x2D', 'x3D', 'border_mask', 'clandmark_mask', 'clandmark_center', 'border_dist2border', 'clandmark_distAvg', 'dff_raw', 'dff_only', 'd_raw', 'd_only', 'event_i_video_segment'])

# %%
# Do all of them at once
from importlib import reload  # Python 3.4+ only.
import h5py
import numpy as np
from analysis.general_utils import aqua_utils, saving_utils
import os
aqua_utils = reload(aqua_utils)


base_paths = ['D:/astro_only/m181129_d190111_c001/data/aqua_bound/', 
              'D:/astro_only/m181129_d190222_c005/day_0/data/aqua_bound/',
              'D:/astro_only/m181129_d190222_c005/day_3/data/aqua_bound/',
              'D:/astro_only/m190129_d190226_cx/day_0/data/aqua_bound/',
              'D:/astro_only/m190129_d190226_cx/day_2/data/aqua_bound/',
              
              'E:/astro_axon_green_red/180912_003/data/aqua_no_bound/',
              'E:/astro_axon_green_red/181012_002/data/aqua_no_bound/',
              'E:/astro_axon_green_red/181022_003/data/aqua_no_bound/'
             ]

for base_path in base_paths:
    print('Processing...', base_path)
              
    mats_folder_path = os.path.join(base_path, 'aqua_res_outputs/')
    save_res_path = os.path.join(base_path, 'aqua_merged/merged.pkl')
    
    print(mats_folder_path)
    print(save_res_path)

     # Results from aqua run
    res_d, input_shape_l, fr_inv, spatial_res = aqua_utils.read_aqua_mats(mats_folder_path)

    print('Input shape:', input_shape_l)
    print('Result keys:', res_d.keys())
    print('Saving...')
    # Save results
    saving_utils.save_pickle([res_d, input_shape_l, fr_inv, spatial_res], save_res_path)
    print('Done!')

    print(input_shape_l, fr_inv, spatial_res)
    print(res_d.keys())
    total_events = len(res_d['tBegin'])
# Out:
# Processing... E:/astro_axon_green_red/181022_003/data/aqua_no_bound/
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs/
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_merged/merged.pkl
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_001_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 0
# 3D index append 0
# (4329,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_002_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 1363
# 3D index append 231361072
# peri
# (4701,)
# (4329,)
# area
# (4701,)
# (4329,)
# circMetric
# (4701,)
# (4329,)
# decayTau
# (4701,)
# (4329,)
# dffMax
# (4701,)
# (4329,)
# dffMax2
# (4701,)
# (4329,)
# (4701,)
# dffMaxFrame
# (4701,)
# (4329,)
# dffMaxPval
# (4701,)
# (4329,)
# dffMaxZ
# (4701,)
# (4329,)
# fall91
# (4701,)
# (4329,)
# rgt1
# (4701, 2)
# (4329, 2)
# rise19
# (4701,)
# (4329,)
# tBegin
# (4701,)
# (4329,)
# tEnd
# (4701,)
# (4329,)
# width11
# (4701,)
# (4329,)
# width55
# (4701,)
# (4329,)
# areaChange
# (4701,)
# (4329,)
# areaChangeRate
# (4701,)
# (4329,)
# areaFrame
# (4701,)
# (4329,)
# propGrow
# (4701,)
# (4329,)
# propGrowOverall
# (4701,)
# (4329,)
# propShrink
# (4701,)
# (4329,)
# propShrinkOverall
# (4701,)
# (4329,)
# t0
# (4701,)
# (4329,)
# t1
# (4701,)
# (4329,)
# x2D
# (4701,)
# (4329,)
# x3D
# (4701,)
# (4329,)
# dff_raw
# (4701, 1363)
# (4329, 1363)
# dff_only
# (4701, 1363)
# (4329, 1363)
# d_raw
# (4701, 1363)
# (4329, 1363)
# d_only
# (4701, 1363)
# (4329, 1363)
# event_i_video_segment
# (4701,)
# (4329,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_003_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 2726
# 3D index append 462722144
# peri
# (4946,)
# (9030,)
# area
# (4946,)
# (9030,)
# circMetric
# (4946,)
# (9030,)
# decayTau
# (4946,)
# (9030,)
# dffMax
# (4946,)
# (9030,)
# dffMax2
# (4946,)
# (9030,)
# (4946,)
# dffMaxFrame
# (4946,)
# (9030,)
# dffMaxPval
# (4946,)
# (9030,)
# dffMaxZ
# (4946,)
# (9030,)
# fall91
# (4946,)
# (9030,)
# rgt1
# (4946, 2)
# (9030, 2)
# rise19
# (4946,)
# (9030,)
# tBegin
# (4946,)
# (9030,)
# tEnd
# (4946,)
# (9030,)
# width11
# (4946,)
# (9030,)
# width55
# (4946,)
# (9030,)
# areaChange
# (4946,)
# (9030,)
# areaChangeRate
# (4946,)
# (9030,)
# areaFrame
# (4946,)
# (9030,)
# propGrow
# (4946,)
# (9030,)
# propGrowOverall
# (4946,)
# (9030,)
# propShrink
# (4946,)
# (9030,)
# propShrinkOverall
# (4946,)
# (9030,)
# t0
# (4946,)
# (9030,)
# t1
# (4946,)
# (9030,)
# x2D
# (4946,)
# (9030,)
# x3D
# (4946,)
# (9030,)
# dff_raw
# (4946, 1363)
# (9030, 1363)
# dff_only
# (4946, 1363)
# (9030, 1363)
# d_raw
# (4946, 1363)
# (9030, 1363)
# d_only
# (4946, 1363)
# (9030, 1363)
# event_i_video_segment
# (4946,)
# (9030,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_004_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 4089
# 3D index append 694083216
# peri
# (4598,)
# (13976,)
# area
# (4598,)
# (13976,)
# circMetric
# (4598,)
# (13976,)
# decayTau
# (4598,)
# (13976,)
# dffMax
# (4598,)
# (13976,)
# dffMax2
# (4598,)
# (13976,)
# (4598,)
# dffMaxFrame
# (4598,)
# (13976,)
# dffMaxPval
# (4598,)
# (13976,)
# dffMaxZ
# (4598,)
# (13976,)
# fall91
# (4598,)
# (13976,)
# rgt1
# (4598, 2)
# (13976, 2)
# rise19
# (4598,)
# (13976,)
# tBegin
# (4598,)
# (13976,)
# tEnd
# (4598,)
# (13976,)
# width11
# (4598,)
# (13976,)
# width55
# (4598,)
# (13976,)
# areaChange
# (4598,)
# (13976,)
# areaChangeRate
# (4598,)
# (13976,)
# areaFrame
# (4598,)
# (13976,)
# propGrow
# (4598,)
# (13976,)
# propGrowOverall
# (4598,)
# (13976,)
# propShrink
# (4598,)
# (13976,)
# propShrinkOverall
# (4598,)
# (13976,)
# t0
# (4598,)
# (13976,)
# t1
# (4598,)
# (13976,)
# x2D
# (4598,)
# (13976,)
# x3D
# (4598,)
# (13976,)
# dff_raw
# (4598, 1363)
# (13976, 1363)
# dff_only
# (4598, 1363)
# (13976, 1363)
# d_raw
# (4598, 1363)
# (13976, 1363)
# d_only
# (4598, 1363)
# (13976, 1363)
# event_i_video_segment
# (4598,)
# (13976,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_005_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 5452
# 3D index append 925444288
# peri
# (4411,)
# (18574,)
# area
# (4411,)
# (18574,)
# circMetric
# (4411,)
# (18574,)
# decayTau
# (4411,)
# (18574,)
# dffMax
# (4411,)
# (18574,)
# dffMax2
# (4411,)
# (18574,)
# (4411,)
# dffMaxFrame
# (4411,)
# (18574,)
# dffMaxPval
# (4411,)
# (18574,)
# dffMaxZ
# (4411,)
# (18574,)
# fall91
# (4411,)
# (18574,)
# rgt1
# (4411, 2)
# (18574, 2)
# rise19
# (4411,)
# (18574,)
# tBegin
# (4411,)
# (18574,)
# tEnd
# (4411,)
# (18574,)
# width11
# (4411,)
# (18574,)
# width55
# (4411,)
# (18574,)
# areaChange
# (4411,)
# (18574,)
# areaChangeRate
# (4411,)
# (18574,)
# areaFrame
# (4411,)
# (18574,)
# propGrow
# (4411,)
# (18574,)
# propGrowOverall
# (4411,)
# (18574,)
# propShrink
# (4411,)
# (18574,)
# propShrinkOverall
# (4411,)
# (18574,)
# t0
# (4411,)
# (18574,)
# t1
# (4411,)
# (18574,)
# x2D
# (4411,)
# (18574,)
# x3D
# (4411,)
# (18574,)
# dff_raw
# (4411, 1363)
# (18574, 1363)
# dff_only
# (4411, 1363)
# (18574, 1363)
# d_raw
# (4411, 1363)
# (18574, 1363)
# d_only
# (4411, 1363)
# (18574, 1363)
# event_i_video_segment
# (4411,)
# (18574,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_006_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 6815
# 3D index append 1156805360
# peri
# (4370,)
# (22985,)
# area
# (4370,)
# (22985,)
# circMetric
# (4370,)
# (22985,)
# decayTau
# (4370,)
# (22985,)
# dffMax
# (4370,)
# (22985,)
# dffMax2
# (4370,)
# (22985,)
# (4370,)
# dffMaxFrame
# (4370,)
# (22985,)
# dffMaxPval
# (4370,)
# (22985,)
# dffMaxZ
# (4370,)
# (22985,)
# fall91
# (4370,)
# (22985,)
# rgt1
# (4370, 2)
# (22985, 2)
# rise19
# (4370,)
# (22985,)
# tBegin
# (4370,)
# (22985,)
# tEnd
# (4370,)
# (22985,)
# width11
# (4370,)
# (22985,)
# width55
# (4370,)
# (22985,)
# areaChange
# (4370,)
# (22985,)
# areaChangeRate
# (4370,)
# (22985,)
# areaFrame
# (4370,)
# (22985,)
# propGrow
# (4370,)
# (22985,)
# propGrowOverall
# (4370,)
# (22985,)
# propShrink
# (4370,)
# (22985,)
# propShrinkOverall
# (4370,)
# (22985,)
# t0
# (4370,)
# (22985,)
# t1
# (4370,)
# (22985,)
# x2D
# (4370,)
# (22985,)
# x3D
# (4370,)
# (22985,)
# dff_raw
# (4370, 1363)
# (22985, 1363)
# dff_only
# (4370, 1363)
# (22985, 1363)
# d_raw
# (4370, 1363)
# (22985, 1363)
# d_only
# (4370, 1363)
# (22985, 1363)
# event_i_video_segment
# (4370,)
# (22985,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_007_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 8178
# 3D index append 1388166432
# peri
# (4979,)
# (27355,)
# area
# (4979,)
# (27355,)
# circMetric
# (4979,)
# (27355,)
# decayTau
# (4979,)
# (27355,)
# dffMax
# (4979,)
# (27355,)
# dffMax2
# (4979,)
# (27355,)
# (4979,)
# dffMaxFrame
# (4979,)
# (27355,)
# dffMaxPval
# (4979,)
# (27355,)
# dffMaxZ
# (4979,)
# (27355,)
# fall91
# (4979,)
# (27355,)
# rgt1
# (4979, 2)
# (27355, 2)
# rise19
# (4979,)
# (27355,)
# tBegin
# (4979,)
# (27355,)
# tEnd
# (4979,)
# (27355,)
# width11
# (4979,)
# (27355,)
# width55
# (4979,)
# (27355,)
# areaChange
# (4979,)
# (27355,)
# areaChangeRate
# (4979,)
# (27355,)
# areaFrame
# (4979,)
# (27355,)
# propGrow
# (4979,)
# (27355,)
# propGrowOverall
# (4979,)
# (27355,)
# propShrink
# (4979,)
# (27355,)
# propShrinkOverall
# (4979,)
# (27355,)
# t0
# (4979,)
# (27355,)
# t1
# (4979,)
# (27355,)
# x2D
# (4979,)
# (27355,)
# x3D
# (4979,)
# (27355,)
# dff_raw
# (4979, 1363)
# (27355, 1363)
# dff_only
# (4979, 1363)
# (27355, 1363)
# d_raw
# (4979, 1363)
# (27355, 1363)
# d_only
# (4979, 1363)
# (27355, 1363)
# event_i_video_segment
# (4979,)
# (27355,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_008_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 9541
# 3D index append 1619527504
# peri
# (4961,)
# (32334,)
# area
# (4961,)
# (32334,)
# circMetric
# (4961,)
# (32334,)
# decayTau
# (4961,)
# (32334,)
# dffMax
# (4961,)
# (32334,)
# dffMax2
# (4961,)
# (32334,)
# (4961,)
# dffMaxFrame
# (4961,)
# (32334,)
# dffMaxPval
# (4961,)
# (32334,)
# dffMaxZ
# (4961,)
# (32334,)
# fall91
# (4961,)
# (32334,)
# rgt1
# (4961, 2)
# (32334, 2)
# rise19
# (4961,)
# (32334,)
# tBegin
# (4961,)
# (32334,)
# tEnd
# (4961,)
# (32334,)
# width11
# (4961,)
# (32334,)
# width55
# (4961,)
# (32334,)
# areaChange
# (4961,)
# (32334,)
# areaChangeRate
# (4961,)
# (32334,)
# areaFrame
# (4961,)
# (32334,)
# propGrow
# (4961,)
# (32334,)
# propGrowOverall
# (4961,)
# (32334,)
# propShrink
# (4961,)
# (32334,)
# propShrinkOverall
# (4961,)
# (32334,)
# t0
# (4961,)
# (32334,)
# t1
# (4961,)
# (32334,)
# x2D
# (4961,)
# (32334,)
# x3D
# (4961,)
# (32334,)
# dff_raw
# (4961, 1363)
# (32334, 1363)
# dff_only
# (4961, 1363)
# (32334, 1363)
# d_raw
# (4961, 1363)
# (32334, 1363)
# d_only
# (4961, 1363)
# (32334, 1363)
# event_i_video_segment
# (4961,)
# (32334,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_009_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 10904
# 3D index append 1850888576
# peri
# (5710,)
# (37295,)
# area
# (5710,)
# (37295,)
# circMetric
# (5710,)
# (37295,)
# decayTau
# (5710,)
# (37295,)
# dffMax
# (5710,)
# (37295,)
# dffMax2
# (5710,)
# (37295,)
# (5710,)
# dffMaxFrame
# (5710,)
# (37295,)
# dffMaxPval
# (5710,)
# (37295,)
# dffMaxZ
# (5710,)
# (37295,)
# fall91
# (5710,)
# (37295,)
# rgt1
# (5710, 2)
# (37295, 2)
# rise19
# (5710,)
# (37295,)
# tBegin
# (5710,)
# (37295,)
# tEnd
# (5710,)
# (37295,)
# width11
# (5710,)
# (37295,)
# width55
# (5710,)
# (37295,)
# areaChange
# (5710,)
# (37295,)
# areaChangeRate
# (5710,)
# (37295,)
# areaFrame
# (5710,)
# (37295,)
# propGrow
# (5710,)
# (37295,)
# propGrowOverall
# (5710,)
# (37295,)
# propShrink
# (5710,)
# (37295,)
# propShrinkOverall
# (5710,)
# (37295,)
# t0
# (5710,)
# (37295,)
# t1
# (5710,)
# (37295,)
# x2D
# (5710,)
# (37295,)
# x3D
# (5710,)
# (37295,)
# dff_raw
# (5710, 1363)
# (37295, 1363)
# dff_only
# (5710, 1363)
# (37295, 1363)
# d_raw
# (5710, 1363)
# (37295, 1363)
# d_only
# (5710, 1363)
# (37295, 1363)
# event_i_video_segment
# (5710,)
# (37295,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_010_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 12267
# 3D index append 2082249648
# peri
# (5639,)
# (43005,)
# area
# (5639,)
# (43005,)
# circMetric
# (5639,)
# (43005,)
# decayTau
# (5639,)
# (43005,)
# dffMax
# (5639,)
# (43005,)
# dffMax2
# (5639,)
# (43005,)
# (5639,)
# dffMaxFrame
# (5639,)
# (43005,)
# dffMaxPval
# (5639,)
# (43005,)
# dffMaxZ
# (5639,)
# (43005,)
# fall91
# (5639,)
# (43005,)
# rgt1
# (5639, 2)
# (43005, 2)
# rise19
# (5639,)
# (43005,)
# tBegin
# (5639,)
# (43005,)
# tEnd
# (5639,)
# (43005,)
# width11
# (5639,)
# (43005,)
# width55
# (5639,)
# (43005,)
# areaChange
# (5639,)
# (43005,)
# areaChangeRate
# (5639,)
# (43005,)
# areaFrame
# (5639,)
# (43005,)
# propGrow
# (5639,)
# (43005,)
# propGrowOverall
# (5639,)
# (43005,)
# propShrink
# (5639,)
# (43005,)
# propShrinkOverall
# (5639,)
# (43005,)
# t0
# (5639,)
# (43005,)
# t1
# (5639,)
# (43005,)
# x2D
# (5639,)
# (43005,)
# x3D
# (5639,)
# (43005,)
# dff_raw
# (5639, 1363)
# (43005, 1363)
# dff_only
# (5639, 1363)
# (43005, 1363)
# d_raw
# (5639, 1363)
# (43005, 1363)
# d_only
# (5639, 1363)
# (43005, 1363)
# event_i_video_segment
# (5639,)
# (43005,)
# E:/astro_axon_green_red/181022_003/data/aqua_no_bound/aqua_res_outputs\181022_003_011_reg.tif-res.mat
# NO REGION
# OPTS <HDF5 group "/res/opts" (48 members)>
# index append: 13630
# 3D index append 2313610720
# peri
# (5682,)
# (48644,)
# area
# (5682,)
# (48644,)
# circMetric
# (5682,)
# (48644,)
# decayTau
# (5682,)
# (48644,)
# dffMax
# (5682,)
# (48644,)
# dffMax2
# (5682,)
# (48644,)
# (5682,)
# dffMaxFrame
# (5682,)
# (48644,)
# dffMaxPval
# (5682,)
# (48644,)
# dffMaxZ
# (5682,)
# (48644,)
# fall91
# (5682,)
# (48644,)
# rgt1
# (5682, 2)
# (48644, 2)
# rise19
# (5682,)
# (48644,)
# tBegin
# (5682,)
# (48644,)
# tEnd
# (5682,)
# (48644,)
# width11
# (5682,)
# (48644,)
# width55
# (5682,)
# (48644,)
# areaChange
# (5682,)
# (48644,)
# areaChangeRate
# (5682,)
# (48644,)
# areaFrame
# (5682,)
# (48644,)
# propGrow
# (5682,)
# (48644,)
# propGrowOverall
# (5682,)
# (48644,)
# propShrink
# (5682,)
# (48644,)
# propShrinkOverall
# (5682,)
# (48644,)
# t0
# (5682,)
# (48644,)
# t1
# (5682,)
# (48644,)
# x2D
# (5682,)
# (48644,)
# x3D
# (5682,)
# (48644,)
# dff_raw
# (5682, 1363)
# (48644, 1363)
# dff_only
# (5682, 1363)
# (48644, 1363)
# d_raw
# (5682, 1363)
# (48644, 1363)
# d_only
# (5682, 1363)
# (48644, 1363)
# event_i_video_segment
# (5682,)
# (48644,)
# 11
# 11
# Input shape: [array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64)]
# Result keys: dict_keys(['peri', 'area', 'circMetric', 'decayTau', 'dffMax', 'dffMax2', 'dffMaxFrame', 'dffMaxPval', 'dffMaxZ', 'fall91', 'rgt1', 'rise19', 'tBegin', 'tEnd', 'width11', 'width55', 'areaChange', 'areaChangeRate', 'areaFrame', 'propGrow', 'propGrowOverall', 'propShrink', 'propShrinkOverall', 't0', 't1', 'x2D', 'x3D', 'dff_raw', 'dff_only', 'd_raw', 'd_only', 'event_i_video_segment'])
# Saving...
# Done!
# [array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64), array([ 412,  412, 1363], dtype=uint64)] 0.097 0.1835
# dict_keys(['peri', 'area', 'circMetric', 'decayTau', 'dffMax', 'dffMax2', 'dffMaxFrame', 'dffMaxPval', 'dffMaxZ', 'fall91', 'rgt1', 'rise19', 'tBegin', 'tEnd', 'width11', 'width55', 'areaChange', 'areaChangeRate', 'areaFrame', 'propGrow', 'propGrowOverall', 'propShrink', 'propShrinkOverall', 't0', 't1', 'x2D', 'x3D', 'dff_raw', 'dff_only', 'd_raw', 'd_only', 'event_i_video_segment'])
